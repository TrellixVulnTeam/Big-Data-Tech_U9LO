# %% [markdown]
# Welcome,
# Below are the keys and tokens of this app

# %%
import tweepy

API_KEY = "O0CSNkR9Dz5oLyOdzzuvwdQjP"
API_KEY_SECRET = "FgPDmbLGzIrHM10gWp6iQwuvfv6aNZvIZP3WQwmvG8xN6ZnIWm"
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAADZrawEAAAAAhIKxuzVkmGNKrlXvEcshMDAFwHc%3DSh7RIjngWP4WII6PJCE8bCJYNGS9xHnhiSdxZ2ISr1fcP7x4AY"

ACCESS_TOKEN = "1508342222336536576-ey4gF7WTTKhbWjSD1d671r7IOitHeE"
ACCESS_TOKEN_SECRET = "ibWHiZUwC35ZmaBpUZznSCwBJ7UOhiBe8DoYletkaEFN"

# %% [markdown]
# Let's make our first query

# %%
import requests

client = tweepy.Client( bearer_token=BEARER_TOKEN, 
                        consumer_key=API_KEY, 
                        consumer_secret=API_KEY_SECRET, 
                        access_token=ACCESS_TOKEN, 
                        access_token_secret=ACCESS_TOKEN_SECRET,
                        wait_on_rate_limit=True)

query = 'from:nntaleb -is:retweet'

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# How at low variance the lognormal masquerades as a normal: example of the distribution of height. https://t.co/2y7QEo1e89
# @TMessi_1 Same as with capital losses treated aa nwgative capital gains.
# Russia's historical approach to business has been bullying neighbors and populations under its rule.
# But, as in the mafia, a bully must always project power &amp; fear in the neighborhood. Getting humiliated by a Zelinsky in the social media age is much worse than the defeat of 1905.
# @stan_yurin @shaarsh2 @kamilkazani Unless tiny.
# @trishankkarthik @trentreese24 @ShawnRuby7 @Porkchop_EXP Death rate does. And vaccination lowers incidence.
# [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]
# @BD_Investing The future tax liability is uncertain? So is the future price.
# China and HK are now proving that, contrary to what we expected in 2020, vaccines have been pivotal in controlling the Covid pandemic.
# [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]
# @carlospapafox 70 years ago?
# @mhomsyy You didn't get it.
# A has 100 mil, all unrealized gains.
# B has 100 mil, no unrealized gains.
# Is NW(A) =NW(B)?
# FINANCE ERROR JOUR
# Now that gov is looking at unrealized capital gains, it's worth noting an error in calculating "net worth": must be reduced by a tax liability paid upon realization.
#
# Few have NW free of future taxation, that is, coming from earned income &amp; realized gains.
# @Pierre_Madani @jaffer_ali1 Mosadeg is 70 years ago, Allende 50.
# Try less anachronism.
# @ChrisCr40781872 You don't seem to understand the MR.
# @MemeticKnight These are NOT Syrians.
# @carlospapafox @ofer_rubin Then remove that crap and please watch my video on disinformation. This IS disinformation.
# @carlospapafox @ofer_rubin This is both nitpicking AND distortion. I block for less than that.
# In theory, being skeptic means exercising one's critical reasoning skills. In practice many are "skeptics" because they have no reasoning skills.
# @jaffer_ali1 You seem to swallow the "proxy" propaganda wholesale, Jaffer.
# @JoeDuncanNYCSGP I thought you knew that I block idiots.
# Disinformation and Fooled by Randomness https://t.co/q9tXBOc0aP via @YouTube
# Disinformation confuses you with ...scale. https://t.co/WKbttlcb4l https://t.co/Lexgr26VpS
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}]
# Is seeking regime change in countries that seek regime change in others really the same thing as seeking regime change in countries that don't seek regime change?
# @omar_ghyad @SaadMaan15 @MQcapital1 @WaelChehab1 I use the Ango-Phoenician commerce driven model in discussions.
# 7/n
# Where our modern notions of nationalism allow anachronistic analyses.
#
# https://t.co/LC3grO2h3x
# @NikosPa39288165 That is precisely my point: military vulnerability.
# @BlackenedToe @aaaaa51607378 No survivorship bias. Cities don't vanish easily.
# @ProcessusDeLevy This is a parallel more technical version
# @MQcapital1 @WaelChehab1 My whole point about NATO
# [{'domain': {'id': '88', 'name': 'Political Body', 'description': 'A section of a government, like The Supreme Court'}, 'entity': {'id': '1016738021939351558', 'name': 'North Atlantic Treaty Organization', 'description': 'North Atlantic Treaty Organization'}}]
# City states like commerce.
# Large states like dominance &amp; national identity.
#
# 6/n
# Democracy is incompatible with large + centralization.
#
# 5/n
# Centralization makes the system weak when large, statist, &amp; anti-commerce. Also comes with a centralized "national identity", &amp; a militaristic bent.
# Small states = benign system. Large centralized states = aggressive, expansionist, hewed to some "national charater/soul".
# 4/n
# Small states are weak militarily  so that they rapidly become vassals.
#
# The Ottomans were (until the end) unintrusive, just wanted payments. Pax Ottomana: like a mafia don you pay the piso &amp; get order.
#
# Some like Anc. Egypt/Ming China/Czarist Russia were centralizers.
# 3/n
# Cline @digkabri showed how centralized nation-states were shellacked during the Bronze age collapse, but Phoenician city-states thrived.
# Phoencs are blamed by marshmallowsoftscholars s.a. @josephinequinn for not existing because they did not have an administrative unity.
# 2/n
# From Pax Romana to Pax Ottomana to Pax NATO (thread):
# Antifragile showed scaling mechanisms: city states/small units outperform large nation-states:
# Switzerland&gt;&gt;Germany
# UAE&gt;&gt;Saudi Arabia
# Taiwan, Sing, HK &gt;&gt; China
# Croatia, Serbia, Montenegro, etc.&gt;&gt; Yugoslavia
# Cyprus &gt;&gt;Greece
# 1/n
# [{'domain': {'id': '88', 'name': 'Political Body', 'description': 'A section of a government, like The Supreme Court'}, 'entity': {'id': '1016738021939351558', 'name': 'North Atlantic Treaty Organization', 'description': 'North Atlantic Treaty Organization'}}]
# Static and Dynamic Hedging is getting more formal.
# We can generalize from atomic payoff classes to something that touches everything, all contracts. https://t.co/9KIR0WTcAO https://t.co/5TAmxzIrG1
# [{'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '781974596148793345', 'name': 'Business & finance'}}, {'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '781974596148793345', 'name': 'Business & finance'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '847888632711061504', 'name': 'Personal finance', 'description': 'Personal finance'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '847894794080722944', 'name': 'Retirement planning', 'description': 'Retirement planning'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '1037075567227494400', 'name': 'Saving and finance', 'description': 'Saving and Finance'}}, {'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '781974596148793345', 'name': 'Business & finance'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '847888632711061504', 'name': 'Personal finance', 'description': 'Personal finance'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '847890600674250753', 'name': 'Beginning investing', 'description': 'Beginning investing'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '847894227845394433', 'name': 'Hedge funds', 'description': 'Hedge funds'}}]
# @DrDamluji @EricMartinRuiz Come to the South.
# @DrDamluji Come to Atlanta
# @financequant @vtchakarova Defenestration is known to cause heart problems.
# @voysnoop @CatalystInvstr @amadeus5689 Arabists are modern Arab nationalists, not the same thing.
# Disinformation and Fooled by Randomness.
#  https://t.co/q9tXBOc0aP
# How nitpickers, trolls, disinformation artists like @ggreenwald/@Snowden play the same game of making you mistake the sensational/anecdotal for the relevant.
# We are not naturally good at dealing with information.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1070710947310788608', 'name': 'Glenn Greenwald', 'description': 'American journalist, lawyer and writer'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1070724848081559554', 'name': 'Edward Snowden', 'description': 'American whistleblower and former National Security Agency contractor'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1423654286492266500', 'name': 'Edward Snowden'}}, {'domain': {'id': '94', 'name': 'Journalist', 'description': "A journalist like 'Anderson Cooper'"}, 'entity': {'id': '1070710947310788608', 'name': 'Glenn Greenwald', 'description': 'American journalist, lawyer and writer'}}]
# 2) This is the result of the 19th Century belief that cities, regions, and people could not be multicultural.
#
# Both Arabism and Western nationalism (France, Italy) after which it has been modeled destroyed Mediterranean multiculturalism.
# @Singularityisc1 @SS_strength I thought you knew that I block idiots.
# Some truth by Rip @SS_strength.
# Principles:
# 1- You WILL NOT get stronger without getting body fat, forget the image of the steroid-laden "ripped".
# 2- Never work out body parts separately.
# 3- Never suffer fools gladly. https://t.co/3kLiv2Qrrt
# @Firsou Speculative, but likely for Thales.
# Thanks to Arabism, Syrian students are completely deprived of their Hellenistic contributions (less so in Lebanon). An entire swath of pre-Islamic history has been blotted out.
# 1000 years of Hellenism erased by the Arabists.
# Below is the list of Greek-Levantine thinkers. https://t.co/Iqed5OlYqM
# @DanAndroyd Nothing wrong following shills IF you know they are shills.
# @DanAndroyd 100%
# @jhamby Yes, correcting to export.
# Never trust a country that produces nuclear weapons, but exports no cars.
# @DanAndroyd Yes, why not?
# @bnuyaminim Any link to mhmd later on?
# No, Vitaly is the one busting propaganda, not the one doing it. https://t.co/gTqi3Zavxf
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}]
# 2) Many lacking in clarity &amp; can't get this.
# https://t.co/ni1TrT3Vsy
# [{'domain': {'id': '88', 'name': 'Political Body', 'description': 'A section of a government, like The Supreme Court'}, 'entity': {'id': '1016738021939351558', 'name': 'North Atlantic Treaty Organization', 'description': 'North Atlantic Treaty Organization'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}]
# Yes, there are Neo-Nazis in Ukraine ( just as there is the Klu Klux Klan in the US ) but the war is not ABOUT Neo-Nazis in Ukraine.
# You can see how Russian propaganda works via Western "independent" Putin promoting journalists. https://t.co/5kaliLkh87
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}]
# There is this game-theoretical argument that nuclear weapons, thanks to MAD (Mutually Assured Destruction) wd cause peace betw superpowers (moving tensions into proxy wars). We swallowed it like suckers.
# The Ukraine war is happening BECAUSE of the existence of nuclear weapons.
# Once sanctions are in, it is very difficult to remove them. Same  with subsidies, cockroaches, termites, and economic theories. https://t.co/MTqqWfPsB2
# @EmanuelDerman @JamesMarsh79 @choffstein @GavinGewecke https://t.co/rSGPbwe3Gb
# @digvijoy_c @trishankkarthik @dzviovich @hjluks Yuuuge difference
# @trishankkarthik @hjluks 5 METs will be OK as you are starting. Plus the estimate is not reliable.
# [{'domain': {'id': '3', 'name': 'TV Shows', 'description': 'Television shows from around the world'}, 'entity': {'id': '10001466882', 'name': 'MLB Baseball', 'description': 'All the latest action from Major League Baseball.'}}, {'domain': {'id': '3', 'name': 'TV Shows', 'description': 'Television shows from around the world'}, 'entity': {'id': '10029304618', 'name': 'MLB Baseball'}}, {'domain': {'id': '6', 'name': 'Sports Event'}, 'entity': {'id': '1488301398039040004', 'name': 'Mets at Cardinals'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '769193663230468096', 'name': 'Baseball'}}, {'domain': {'id': '12', 'name': 'Sports Team', 'description': 'A sports team organization, like Arsenal and the Boston Celtics'}, 'entity': {'id': '769193634889474048', 'name': 'New York Mets'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '769193602169704448', 'name': 'MLB'}}]
# Don Corleone to his son: after my death, he from within your circle who will invite you to a sit down meeting will betray you and get you assassinated. https://t.co/9dmwLNab1E
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '864931126132985856', 'name': 'Vladimir Putin', 'description': 'President of Russia Vladimir Putin'}}]
# @JohnJcollias @GadSaad Professors have power.
# @KhizrMd @PZalloua Persian. Contains loan words.
# @jadabdala @faleflix A spy went to taste. This is the real thing.
# @trishankkarthik @Gallagher4NY @hjluks Elevation is still under 2%
# @trishankkarthik @Gallagher4NY @hjluks Speed and some elevation.
# @trishankkarthik @hjluks Also use 5 zones in the setup
# @trishankkarthik @hjluks Mets need to be &gt; 6
# [{'domain': {'id': '3', 'name': 'TV Shows', 'description': 'Television shows from around the world'}, 'entity': {'id': '10001466882', 'name': 'MLB Baseball', 'description': 'All the latest action from Major League Baseball.'}}, {'domain': {'id': '3', 'name': 'TV Shows', 'description': 'Television shows from around the world'}, 'entity': {'id': '10029304618', 'name': 'MLB Baseball'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '769193663230468096', 'name': 'Baseball'}}, {'domain': {'id': '12', 'name': 'Sports Team', 'description': 'A sports team organization, like Arsenal and the Boston Celtics'}, 'entity': {'id': '769193634889474048', 'name': 'New York Mets'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '769193602169704448', 'name': 'MLB'}}]
# @Stefano_Peron @hjluks @trishankkarthik I was waiting for someone to pick on it!
# @DrDamluji Ancestral house. https://t.co/b1BBj1eZpj
# @DrDamluji Amioun is at least as good
# Dynamic Hedging Explained, formalized, before showing its shortcomings. https://t.co/P9dlQ9DfkD
# @hjluks @trishankkarthik Combination of 4 modalities, includes mountain hiking, cycling, running, and stairs climber. No elliptical.
# [{'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '847868745150119936', 'name': 'Home & family', 'description': 'Hobbies and interests'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '847901134601633792', 'name': 'Rock climbing', 'description': 'Climbing'}}, {'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '839159814991167489', 'name': 'Travel', 'description': 'Travel'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '839160129752686593', 'name': 'General Travel', 'description': 'General Travel'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '839161975712067584', 'name': 'Travel Actions', 'description': 'This entity includes all conversations about travel and vacation.'}}]
# Ask yourself if a whistleblower is trying to fix the system for the benefit of ordinary citizens, or trying to harm it out of spite.
# 2) There is a ح ח  in Ingush but seemingly no ع  ע.
# Incidentally Chechens are J1, Igush J2 @PZalloua
#
# https://t.co/GWGzHz6BQX
# @GraecoSyrian A lot of these are Persian and Islamic loan words.
# Things I learned today (Philology):
# The North Caucasian languages (Chechen, Ingush ?) have the Semitic voiceless pharyngeal fricative ح ח  and the  ʕa: ع  ע.
#
# https://t.co/xbRJjGO4vk

# %%
auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True)

if(api.verify_credentials):
    print("you have been verified")
else:
    print("You have not been verified")

tweet_id = '1228393702244134912'
result = api.get_status(tweet_id)
#date = result.created_at.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# you have been verified
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# /home/tonno/Desktop/1^ anno Data Science/Big Data Tech/twitterAPI/twitterIntro.ipynb Cell 5' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/home/tonno/Desktop/1%5E%20anno%20Data%20Science/Big%20Data%20Tech/twitterAPI/twitterIntro.ipynb#ch0000004?line=7'>8</a>     print("You have not been verified")
#      <a href='vscode-notebook-cell:/home/tonno/Desktop/1%5E%20anno%20Data%20Science/Big%20Data%20Tech/twitterAPI/twitterIntro.ipynb#ch0000004?line=9'>10</a> tweet_id = '1228393702244134912'
# ---> <a href='vscode-notebook-cell:/home/tonno/Desktop/1%5E%20anno%20Data%20Science/Big%20Data%20Tech/twitterAPI/twitterIntro.ipynb#ch0000004?line=10'>11</a> result = api.get_status(tweet_id)
#
# File ~/Desktop/università/Data science/1^ anno/Big Data Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=43'>44</a> kwargs['payload_list'] = payload_list
#      <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=44'>45</a> kwargs['payload_type'] = payload_type
# ---> <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=45'>46</a> return method(*args, **kwargs)
#
# File ~/Desktop/università/Data science/1^ anno/Big Data Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py:896, in API.get_status(self, id, **kwargs)
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=862'>863</a> @payload('status')
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=863'>864</a> def get_status(self, id, **kwargs):
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=864'>865</a>     """get_status(id, *, trim_user, include_my_retweet, include_entities, \
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=865'>866</a>                   include_ext_alt_text, include_card_uri)
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=866'>867</a>
#    (...)
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=893'>894</a>     https://developer.twitter.com/en/docs/twitter-api/v1/tweets/post-and-engage/api-reference/get-statuses-show-id
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=894'>895</a>     """
# --> <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=895'>896</a>     return self.request(
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=896'>897</a>         'GET', 'statuses/show', endpoint_parameters=(
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=897'>898</a>             'id', 'trim_user', 'include_my_retweet', 'include_entities',
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=898'>899</a>             'include_ext_alt_text', 'include_card_uri'
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=899'>900</a>         ), id=id, **kwargs
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=900'>901</a>     )
#
# File ~/Desktop/università/Data science/1^ anno/Big Data Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py:257, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=254'>255</a>     raise BadRequest(resp)
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=255'>256</a> if resp.status_code == 401:
# --> <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=256'>257</a>     raise Unauthorized(resp)
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=257'>258</a> if resp.status_code == 403:
#     <a href='file:///home/tonno/Desktop/universit%C3%A0/Data%20science/1%5E%20anno/Big%20Data%20Tech/twitterAPI/venv/lib/python3.9/site-packages/tweepy/api.py?line=258'>259</a>     raise Forbidden(resp)
#
# Unauthorized: 401 Unauthorized
# 32 - Could not authenticate you.
